# %%
# Read in data from ETL.py file
# %run '../scripts/Revenue_model.py' '../scripts/paths.json'
# Out:
# 22/10/06 14:27:29 WARN package: Truncated the string representation of a plan since it was too large. This behavior can be adjusted by setting 'spark.sql.debug.maxToStringFields'.
# [Stage 325:==================================================>      (8 + 1) / 9]
# 22/10/06 14:30:16 WARN DAGScheduler: Broadcasting large task binary with size 1337.4 KiB
# 22/10/06 14:30:17 WARN DAGScheduler: Broadcasting large task binary with size 1337.5 KiB
# 22/10/06 14:30:18 WARN DAGScheduler: Broadcasting large task binary with size 1341.5 KiB
# 22/10/06 14:30:20 WARN DAGScheduler: Broadcasting large task binary with size 1454.2 KiB
# 22/10/06 14:30:26 WARN DAGScheduler: Broadcasting large task binary with size 1515.9 KiB
# 22/10/06 14:30:29 WARN DAGScheduler: Broadcasting large task binary with size 1636.9 KiB
# 22/10/06 14:30:33 WARN DAGScheduler: Broadcasting large task binary with size 1879.0 KiB
# 22/10/06 14:30:36 WARN DAGScheduler: Broadcasting large task binary with size 2.3 MiB
# ...
