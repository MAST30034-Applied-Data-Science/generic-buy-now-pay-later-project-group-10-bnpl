# %% [markdown]
# ## Part 2: Outlier Analysis

# %%
# %run "../scripts/outlier.py"
# Out:
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 22/09/13 17:16:11 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# 22/09/13 17:16:12 WARN Utils: Service 'SparkUI' could not bind on port 4040. Attempting port 4041.
# Count before outliers:  14195505
# Count after outlier exclusion 1:  13614675

# %%
import matplotlib.pyplot as plt

fig = plt.figure(figsize =(10, 7))
plt.boxplot(aggregated_revenue_pd['sum(dollar_value)'])
plt.show()
